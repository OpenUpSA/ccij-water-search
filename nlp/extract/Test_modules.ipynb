# %%
from util import extract_content
from util import enrich_json_process
from util import nlp_process
from util import google_api_query
from util import pollution_detail
import pandas as pd

# %%
# Test Google API query
urls_use=google_api_query.get_urls('water\ scarcity\ news',1)
df_api_result=google_api_query.alldata(urls_use)
df_api_result
# Out:
# C:\Users\annda\1\Desktop\openup\ccij-water-search\nlp\util\google_api_query.py:65: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_draft=json_normalize(result_l)
#                                                 title  \
# 0   ▷ Official news concerning Water scarcity 2020...
# 1   but many developing countries will face water ...
# 2   Science/Nature | Water scarcity: A looming cri...
# 3   UCLA Forms Water Technology Research Center to...
# 4   News: Publications: Sandia Lab News: March ......
# ..                                                ...
# 94  Waste Not Good News, Bad News: The Current Sta...
# 95  Speaker to present 'Global Water Scarcity' in ...
# 96  Weekly Urban News Update: NENA Water Scarcity ...
# 97  Survey Reveals Half of Americans Don't Believe...
# 98                                     Water Scarcity
#
#                                                   url keywords  \
# ...

# %%
# Test find topic
df_enriched = enrich_json_process.json_to_df('enriched_articles.json')
df_topic=enrich_json_process.column_unpack(df_enriched,'topics','url')
topic_result=enrich_json_process.find_topic(df_enriched,'drought',0.5,'url')
topic_result
# Out:
# C:\Users\annda\1\Desktop\openup\ccij-water-search\nlp\util\enrich_json_process.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_enriched = json_normalize(pd.Series(open(filename).readlines()).apply(json.loads))
# C:\Users\annda\1\Desktop\openup\ccij-water-search\nlp\util\enrich_json_process.py:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_new=json_normalize(df_single['new'].tolist())
#                                                   url  \
# 0   http://english.ahram.org.eg/NewsContent/1/64/3...
# 1   http://opiniojuris.org/2020/05/04/so-close-yet...
# 2   http://opiniojuris.org/2020/05/04/so-close-yet...
# 3   http://www.angop.ao/angola/en_us/noticias/poli...
# 4   http://www.daily-mail.co.zm/beaconing-global-w...
# ..                                                ...
# 79  https://www.weforum.org/agenda/2020/01/zimbabw...
# ...

# %%
# Test find pollutant info
df_pollution_adi = enrich_json_process.json_to_df('enriched_articles-pollution.json')
df_entity =enrich_json_process.column_unpack(df_pollution_adi,'entities','url')
pollution_info=pollution_detail.get_pollution_info(df_entity)
pollution_info
# Out:
# C:\Users\annda\1\Desktop\openup\ccij-water-search\nlp\util\enrich_json_process.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_enriched = json_normalize(pd.Series(open(filename).readlines()).apply(json.loads))
# C:\Users\annda\1\Desktop\openup\ccij-water-search\nlp\util\enrich_json_process.py:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_new=json_normalize(df_single['new'].tolist())
# newtype                                                url                dis  \
# 0              http://accesswdun.com/article/2018/3/642943           [Cancer]
# 1        http://bigcountryhomepage.com/news/main-news/r...                NaN
# 2        http://capitalpress.com/Washington/20180302/ne...           [Cancer]
# 3        http://carrollcountytimes.com/ct-epa-plan-lake...                NaN
# 4        http://chicagotribune.com/news/nationworld/mid...                NaN
# ...

# %%
# Test extracting content
links=df_pollution_adi.url.unique().tolist()
[df_pollution_with_content,failed_url]=extract_content.get_content(links)
df_pollution_with_content.to_csv('pollution_articles_adi_with_content.csv')
df_pollution_with_content
# Out:
#                                                    url  \
# 2    http://abc6.com/story/37634397/us-utilities-fi...
# 9    http://bigcountryhomepage.com/news/main-news/r...
# 11   http://calgaryherald.com/pmn/business-pmn/trum...
# 12   http://capitalpress.com/Washington/20180302/ne...
# 13   http://carrollcountytimes.com/ct-epa-plan-lake...
# ..                                                 ...
# 332  http://vietnamnews.vn/environment/423696/water...
# 336  http://wane.com/2018/03/07/epa-plan-seeks-cuts...
# 346  http://wfmj.com/story/37673804/epa-plan-seeks-...
# 350  http://windsorstar.com/pmn/news-pmn/epa-plan-s...
# 351  http://wisfarmer.com/story/news/state/2018/03/...
#
#                                                  title  \
# 2     Providence, RI and New Bedford, MA News, Weather
# 9    Report: Major Texas industrial facilities rank...
# 11   Trump EPA moves to roll back more rules on fue...
# 12   NewsBreak: US utilities find water pollution a...
# ...

# %%
# Test NLP processing
df_pollution_with_content=pd.read_csv('pollution_articles_adi_with_content.csv')
nlp_result=nlp_process.process(df_pollution_with_content,'pollution','text')
nlp_result
# Out:
# C:\Users\annda\anaconda2\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\annda\anaconda2\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      Unnamed: 0                                                url  \
# 0             2  http://abc6.com/story/37634397/us-utilities-fi...
# ...
